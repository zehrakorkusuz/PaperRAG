# %%
import time
from difflib import SequenceMatcher
import os
import json
import logging
from pathlib import Path
from docling.document_converter import DocumentConverter
from docling.chunking import HybridChunker
from docling.chunking import HybridChunker
from docling.datamodel.pipeline_options import PdfPipelineOptions
from llmsherpa.readers import LayoutPDFReader
from paperrag.document.document_loader import DocumentLoader
from paperrag.document.figure_parser import FigureExtractor
from docling_core.types.doc import ImageRefMode, PictureItem, TableItem
from docling.datamodel.base_models import FigureElement, InputFormat, Table
from docling.document_converter import DocumentConverter, PdfFormatOption
import nest_asyncio 

nest_asyncio.apply()

# Setup logging
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

IMAGE_RESOLUTION_SCALE = 2.0

# %%
# Define parser functions
def docling_parser(document_path):
    """Docling parser implementation."""
    start_time = time.time()
    try:
        converter = DocumentConverter()
        doc = converter.convert(document_path).document
        # output = result.document.export_to_markdown()
        chunker = HybridChunker()
        chunk_iter = chunker.chunk(dl_doc=doc)
        output = chunker.iter
    except Exception as e:
        logger.error(f"Docling parser failed: {e}")
        output = ""
    elapsed_time = time.time() - start_time
    return output, elapsed_time

pipeline_options = PdfPipelineOptions()
pipeline_options.images_scale = IMAGE_RESOLUTION_SCALE
pipeline_options.generate_page_images = True
pipeline_options.generate_picture_images = True

def docling_images_parser(document_path):
    pipeline_options = PdfPipelineOptions()
    pipeline_options.images_scale = IMAGE_RESOLUTION_SCALE
    pipeline_options.generate_page_images = True
    pipeline_options.generate_picture_images = True

    doc_converter = DocumentConverter(
        format_options={
            InputFormat.PDF: PdfFormatOption(pipeline_options=pipeline_options)
        }
    )

    start_time = time.time()
    conv_res = doc_converter.convert(document_path)

    chunker = HybridChunker()
    chunk_iter = chunker.chunk(dl_doc=conv_res.document)
    output = chunk_iter

    output_dir = Path("output_images")
    output_dir.mkdir(parents=True, exist_ok=True)
    doc_filename = conv_res.input.file.stem

    table_counter = 0
    picture_counter = 0
    for element, _level in conv_res.document.iterate_items():
        if isinstance(element, TableItem):
            table_counter += 1
            element_image_filename = output_dir / f"{doc_filename}-table-{table_counter}.png"
            with element_image_filename.open("wb") as fp:
                element.get_image(conv_res.document).save(fp, "PNG")
        if isinstance(element, PictureItem):
            picture_counter += 1
            element_image_filename = output_dir / f"{doc_filename}-picture-{picture_counter}.png"
            with element_image_filename.open("wb") as fp:
                element.get_image(conv_res.document).save(fp, "PNG")

    output = conv_res.document.export_to_markdown()
    elapsed_time = time.time() - start_time
    return output, elapsed_time

def llmsherpa_parser(document_path):
    """LLMSherpa parser implementation."""
    llmsherpa_api_url = "http://localhost:5010/api/parseDocument?renderFormat=all"
    pdf_reader = LayoutPDFReader(llmsherpa_api_url)
    start_time = time.time()
    try:
        doc = pdf_reader.read_pdf(document_path)
        doc_json = doc.to_json()
    except Exception as e:
        logger.error(f"LLMSherpa parser failed: {e}")
        output = ""
    elapsed_time = time.time() - start_time
    return output, elapsed_time

async def custom_llmsherpa_parser(document_path): # also include pdf_figures
    """Custom LLMSherpa parser implementation."""
    start_time = time.time()
    #base_dir = os.path.abspath(os.path.dirname(__file__))
    base_dir = os.getcwd()
    output_dir = os.path.join(base_dir, "data", "figures")
    os.makedirs(output_dir, exist_ok=True)

    loader = DocumentLoader(pdf_path=document_path, output_dir=output_dir, async_mode=True)
    try:
        documents, stats = await loader.load_async()
        output = json.dumps([vars(d) for d in documents], indent=4)
    except Exception as e:
        logger.error(f"Custom LLMSherpa parser failed: {e}")
        output = ""
    elapsed_time = time.time() - start_time
    return output, elapsed_time

def pdffigures2_parser(document_path):
    """PDFFigures2 parser implementation."""
    # base_dir = os.path.abspath(os.path.dirname(__file__))
    base_dir = os.getcwd()
    output_dir = os.path.join(base_dir, "data", "figures")
    os.makedirs(output_dir, exist_ok=True)
    extractor = FigureExtractor(document_path, output_dir)
    start_time = time.time()
    try:
        figures = extractor.extract_figures()
        output = json.dumps([vars(fig) for fig in figures], indent=4)
    except Exception as e:
        logger.error(f"PDFFigures2 parser failed: {e}")
        output = ""
    elapsed_time = time.time() - start_time
    return output, elapsed_time

# %%
import nest_asyncio
import asyncio

nest_asyncio.apply()

def evaluate_parsers(parsers, document_path):
    """Evaluate parsers for speed and output."""
    results = {}

    for parser_name, parser_function in parsers.items():
        logger.info(f"Evaluating {parser_name}...")

        if asyncio.iscoroutinefunction(parser_function):
            # Handle async parsers
            output, elapsed_time = asyncio.run(parser_function(document_path))
        else:
            output, elapsed_time = parser_function(document_path)

        # Basic metrics (e.g., output length)
        output_length = len(output) if output else 0

        # Store results
        results[parser_name] = {
            "elapsed_time": elapsed_time,
            "output_length": output_length,
            "output": output
        }

    return results

# %%
document_path = "/Users/zehrakorkusuz/PaperRAG/data/2501.12691v1.pdf"

# Define parsers
parsers = {
    "Docling": docling_parser,
    "LLMSherpa": llmsherpa_parser,
    "Custom LLMSherpa": custom_llmsherpa_parser, #also include pdf_figures2
    #"PDFFigures2": pdffigures2_parser,
    "Docling Images": docling_images_parser
}

# Run evaluation
evaluation_results = evaluate_parsers(parsers, document_path)

# Print results: Number of tables extracted; number of images extracted; number of figures extracted; qualitative evaluation of the output
for parser_name, metrics in evaluation_results.items():
    logger.info(f"\nResults for {parser_name}:")
    logger.info(f"  Elapsed time: {metrics['elapsed_time']:.2f} seconds")
    logger.info(f"  Output length: {metrics['output_length']} characters")
    logger.info(f"  Sample output: {metrics['output']}")
# Out:
# 2025-01-23 20:25:10,816 - __main__ - INFO - Evaluating Docling...
# 2025-01-23 20:25:10,934 - docling.document_converter - INFO - Going to convert document batch...
# 2025-01-23 20:25:11,113 - urllib3.connectionpool - DEBUG - https://huggingface.co:443 "GET /api/models/ds4sd/docling-models/revision/v2.1.0 HTTP/1.1" 200 1264
# 2025-01-23 20:25:11,156 - docling.utils.accelerator_utils - INFO - Accelerator device: 'mps'
# 2025-01-23 20:25:18,003 - docling.utils.accelerator_utils - INFO - Accelerator device: 'mps'
# 2025-01-23 20:25:20,665 - docling_ibm_models.layoutmodel.layout_predictor - DEBUG - LayoutPredictor settings: {'safe_tensors_file': '/Users/zehrakorkusuz/.cache/huggingface/hub/models--ds4sd--docling-models/snapshots/36bebf56681740529abd09f5473a93a69373fbf0/model_artifacts/layout/model.safetensors', 'device': 'mps', 'num_threads': 4, 'image_size': 640, 'threshold': 0.3}
# 2025-01-23 20:25:20,670 - docling.utils.accelerator_utils - INFO - Accelerator device: 'mps'
# 2025-01-23 20:25:21,373 - docling.pipeline.base_pipeline - INFO - Processing document 2501.12691v1.pdf
# 2025-01-23 20:25:30,030 - docling.pipeline.base_pipeline - DEBUG - Finished converting page batch time=278603.666
# 2025-01-23 20:25:35,528 - docling.pipeline.base_pipeline - DEBUG - Finished converting page batch time=278609.164
# 2025-01-23 20:25:40,902 - docling.pipeline.base_pipeline - DEBUG - Finished converting page batch time=278614.539
# 2025-01-23 20:25:58,922 - docling.pipeline.base_pipeline - DEBUG - Finished converting page batch time=278632.557
# 2025-01-23 20:26:14,575 - docling.pipeline.base_pipeline - DEBUG - Finished converting page batch time=278648.210
# 2025-01-23 20:26:30,269 - docling.pipeline.base_pipeline - DEBUG - Finished converting page batch time=278663.904
# 2025-01-23 20:26:35,764 - docling.pipeline.base_pipeline - DEBUG - Finished converting page batch time=278669.399
# 2025-01-23 20:26:37,035 - docling.document_converter - INFO - Finished converting document 2501.12691v1.pdf in 86.19 sec.
# 2025-01-23 20:26:37,456 - urllib3.connectionpool - DEBUG - https://huggingface.co:443 "HEAD /sentence-transformers/all-MiniLM-L6-v2/resolve/main/tokenizer_config.json HTTP/1.1" 200 0
# Token indices sequence length is longer than the specified maximum sequence length for this model (736 > 512). Running this sequence through the model will result in indexing errors
# 2025-01-23 20:26:38,566 - __main__ - ERROR - Docling parser failed: 'HybridChunker' object has no attribute 'iter'
# 2025-01-23 20:26:38,615 - __main__ - INFO - Evaluating LLMSherpa...
# 2025-01-23 20:26:38,627 - urllib3.connectionpool - DEBUG - Starting new HTTP connection (1): localhost:5010
# 2025-01-23 20:29:23,033 - urllib3.connectionpool - DEBUG - http://localhost:5010 "POST /api/parseDocument?renderFormat=all HTTP/1.1" 200 0
# 2025-01-23 20:29:23,188 - __main__ - ERROR - LLMSherpa parser failed: 'Document' object has no attribute 'to_json'
# 2025-01-23 20:29:23,196 - __main__ - INFO - Evaluating Custom LLMSherpa...
# 2025-01-23 20:29:23,218 - root - DEBUG - Initialized DocumentLoader with pdf_path=/Users/zehrakorkusuz/PaperRAG/data/2501.12691v1.pdf, output_dir=/Users/zehrakorkusuz/PaperRAG/src/paperrag/eval/data/figures, async_mode=True
# 2025-01-23 20:29:23,220 - root - INFO - Starting asynchronous loading process.
# 2025-01-23 20:29:23,222 - root - DEBUG - Starting PDF processing and figure extraction...
# 2025-01-23 20:29:23,236 - root - DEBUG - Uploading /Users/zehrakorkusuz/PaperRAG/data/2501.12691v1.pdf to http://localhost:5001/extract for extraction
# 2025-01-23 20:29:23,259 - root - INFO - Extracting figures and tables from /Users/zehrakorkusuz/PaperRAG/data/2501.12691v1.pdf
# 2025-01-23 20:29:23,268 - root - DEBUG - Setting up output directory: /Users/zehrakorkusuz/PaperRAG/src/paperrag/eval/data/figures
# 2025-01-23 20:29:23,274 - root - INFO - Output directory is set to /Users/zehrakorkusuz/PaperRAG/src/paperrag/eval/data/figures
# 2025-01-23 20:29:23,312 - urllib3.connectionpool - DEBUG - Starting new HTTP connection (1): localhost:5001
# 2025-01-23 20:29:37,895 - urllib3.connectionpool - DEBUG - http://localhost:5001 "POST /extract HTTP/1.1" 200 353
# 2025-01-23 20:29:37,897 - root - INFO - Received response: 200 - {"figures":["/app/outputs/2501.12691v1-Figure3-1.png","/app/outputs/2501.12691v1-Figure2-1.png","/app/outputs/2501.12691v1-Figure1-1.png","/app/outputs/2501.12691v1-Figure5-1.png","/app/outputs/2501.12691v1-Figure4-1.png"],"metadata_file":"2501.12691v1.json","metadata_filename":"2501.12691v1.json","num_figures":5,"num_tables":0,"pages":0,"tables":[]}
#
# 2025-01-23 20:29:37,899 - root - INFO - Extraction successful for /Users/zehrakorkusuz/PaperRAG/data/2501.12691v1.pdf
# 2025-01-23 20:29:37,901 - root - DEBUG - Received response data: {
#   "figures": [
#     "/app/outputs/2501.12691v1-Figure3-1.png",
#     "/app/outputs/2501.12691v1-Figure2-1.png",
#     "/app/outputs/2501.12691v1-Figure1-1.png",
#     "/app/outputs/2501.12691v1-Figure5-1.png",
#     "/app/outputs/2501.12691v1-Figure4-1.png"
#   ],
#   "metadata_file": "2501.12691v1.json",
#   "metadata_filename": "2501.12691v1.json",
#   "num_figures": 5,
#   "num_tables": 0,
#   "pages": 0,
#   "tables": []
# }
# 2025-01-23 20:29:37,904 - root - DEBUG - download_extracted_data called with output_dir: /Users/zehrakorkusuz/PaperRAG/src/paperrag/eval/data/figures
# 2025-01-23 20:29:37,906 - root - DEBUG - Starting download from http://localhost:5001/download/2501.12691v1.json
# 2025-01-23 20:29:37,914 - urllib3.connectionpool - DEBUG - Starting new HTTP connection (1): localhost:5001
# 2025-01-23 20:29:37,929 - urllib3.connectionpool - DEBUG - http://localhost:5001 "GET /download/2501.12691v1.json HTTP/1.1" 200 18819
# 2025-01-23 20:29:37,934 - root - DEBUG - Downloaded file to /Users/zehrakorkusuz/PaperRAG/src/paperrag/eval/data/figures/2501.12691v1.json
# 2025-01-23 20:29:37,935 - root - DEBUG - Downloading figures: ['/app/outputs/2501.12691v1-Figure3-1.png', '/app/outputs/2501.12691v1-Figure2-1.png', '/app/outputs/2501.12691v1-Figure1-1.png', '/app/outputs/2501.12691v1-Figure5-1.png', '/app/outputs/2501.12691v1-Figure4-1.png']
# 2025-01-23 20:29:37,937 - root - DEBUG - Original figure filename: /app/outputs/2501.12691v1-Figure3-1.png
# 2025-01-23 20:29:37,938 - root - DEBUG - Sanitized figure filename: 2501.12691v1-Figure3-1.png
# 2025-01-23 20:29:37,939 - root - DEBUG - Figure download URL: http://localhost:5001/download/2501.12691v1-Figure3-1.png
# 2025-01-23 20:29:37,940 - root - DEBUG - Figure output path: /Users/zehrakorkusuz/PaperRAG/src/paperrag/eval/data/figures/2501.12691v1-Figure3-1.png
# 2025-01-23 20:29:37,941 - root - DEBUG - Starting download from http://localhost:5001/download/2501.12691v1-Figure3-1.png
# 2025-01-23 20:29:37,947 - urllib3.connectionpool - DEBUG - Starting new HTTP connection (1): localhost:5001
# 2025-01-23 20:29:37,960 - urllib3.connectionpool - DEBUG - http://localhost:5001 "GET /download/2501.12691v1-Figure3-1.png HTTP/1.1" 200 444746
# 2025-01-23 20:29:37,977 - root - DEBUG - Downloaded file to /Users/zehrakorkusuz/PaperRAG/src/paperrag/eval/data/figures/2501.12691v1-Figure3-1.png
# 2025-01-23 20:29:37,978 - root - DEBUG - Original figure filename: /app/outputs/2501.12691v1-Figure2-1.png
# 2025-01-23 20:29:37,979 - root - DEBUG - Sanitized figure filename: 2501.12691v1-Figure2-1.png
# 2025-01-23 20:29:37,980 - root - DEBUG - Figure download URL: http://localhost:5001/download/2501.12691v1-Figure2-1.png
# 2025-01-23 20:29:37,982 - root - DEBUG - Figure output path: /Users/zehrakorkusuz/PaperRAG/src/paperrag/eval/data/figures/2501.12691v1-Figure2-1.png
# 2025-01-23 20:29:37,983 - root - DEBUG - Starting download from http://localhost:5001/download/2501.12691v1-Figure2-1.png
# 2025-01-23 20:29:37,995 - urllib3.connectionpool - DEBUG - Starting new HTTP connection (1): localhost:5001
# 2025-01-23 20:29:38,009 - urllib3.connectionpool - DEBUG - http://localhost:5001 "GET /download/2501.12691v1-Figure2-1.png HTTP/1.1" 200 788261
# 2025-01-23 20:29:38,041 - root - DEBUG - Downloaded file to /Users/zehrakorkusuz/PaperRAG/src/paperrag/eval/data/figures/2501.12691v1-Figure2-1.png
# 2025-01-23 20:29:38,042 - root - DEBUG - Original figure filename: /app/outputs/2501.12691v1-Figure1-1.png
# 2025-01-23 20:29:38,043 - root - DEBUG - Sanitized figure filename: 2501.12691v1-Figure1-1.png
# 2025-01-23 20:29:38,045 - root - DEBUG - Figure download URL: http://localhost:5001/download/2501.12691v1-Figure1-1.png
# 2025-01-23 20:29:38,046 - root - DEBUG - Figure output path: /Users/zehrakorkusuz/PaperRAG/src/paperrag/eval/data/figures/2501.12691v1-Figure1-1.png
# 2025-01-23 20:29:38,047 - root - DEBUG - Starting download from http://localhost:5001/download/2501.12691v1-Figure1-1.png
# 2025-01-23 20:29:38,050 - urllib3.connectionpool - DEBUG - Starting new HTTP connection (1): localhost:5001
# 2025-01-23 20:29:38,061 - urllib3.connectionpool - DEBUG - http://localhost:5001 "GET /download/2501.12691v1-Figure1-1.png HTTP/1.1" 200 757834
# 2025-01-23 20:29:38,085 - root - DEBUG - Downloaded file to /Users/zehrakorkusuz/PaperRAG/src/paperrag/eval/data/figures/2501.12691v1-Figure1-1.png
# 2025-01-23 20:29:38,086 - root - DEBUG - Original figure filename: /app/outputs/2501.12691v1-Figure5-1.png
# 2025-01-23 20:29:38,087 - root - DEBUG - Sanitized figure filename: 2501.12691v1-Figure5-1.png
# 2025-01-23 20:29:38,088 - root - DEBUG - Figure download URL: http://localhost:5001/download/2501.12691v1-Figure5-1.png
# 2025-01-23 20:29:38,089 - root - DEBUG - Figure output path: /Users/zehrakorkusuz/PaperRAG/src/paperrag/eval/data/figures/2501.12691v1-Figure5-1.png
# 2025-01-23 20:29:38,091 - root - DEBUG - Starting download from http://localhost:5001/download/2501.12691v1-Figure5-1.png
# 2025-01-23 20:29:38,095 - urllib3.connectionpool - DEBUG - Starting new HTTP connection (1): localhost:5001
# 2025-01-23 20:29:38,107 - urllib3.connectionpool - DEBUG - http://localhost:5001 "GET /download/2501.12691v1-Figure5-1.png HTTP/1.1" 200 593589
# 2025-01-23 20:29:38,123 - root - DEBUG - Downloaded file to /Users/zehrakorkusuz/PaperRAG/src/paperrag/eval/data/figures/2501.12691v1-Figure5-1.png
# 2025-01-23 20:29:38,125 - root - DEBUG - Original figure filename: /app/outputs/2501.12691v1-Figure4-1.png
# 2025-01-23 20:29:38,126 - root - DEBUG - Sanitized figure filename: 2501.12691v1-Figure4-1.png
# 2025-01-23 20:29:38,127 - root - DEBUG - Figure download URL: http://localhost:5001/download/2501.12691v1-Figure4-1.png
# 2025-01-23 20:29:38,128 - root - DEBUG - Figure output path: /Users/zehrakorkusuz/PaperRAG/src/paperrag/eval/data/figures/2501.12691v1-Figure4-1.png
# 2025-01-23 20:29:38,129 - root - DEBUG - Starting download from http://localhost:5001/download/2501.12691v1-Figure4-1.png
# 2025-01-23 20:29:38,140 - urllib3.connectionpool - DEBUG - Starting new HTTP connection (1): localhost:5001
# 2025-01-23 20:29:38,160 - urllib3.connectionpool - DEBUG - http://localhost:5001 "GET /download/2501.12691v1-Figure4-1.png HTTP/1.1" 200 439375
# 2025-01-23 20:29:38,202 - root - DEBUG - Downloaded file to /Users/zehrakorkusuz/PaperRAG/src/paperrag/eval/data/figures/2501.12691v1-Figure4-1.png
# 2025-01-23 20:29:38,206 - root - DEBUG - Downloading tables: []
# 2025-01-23 20:29:38,209 - root - INFO - Downloading metadata for /Users/zehrakorkusuz/PaperRAG/data/2501.12691v1.pdf
# 2025-01-23 20:29:38,213 - root - INFO - Extracting figure metadata for /Users/zehrakorkusuz/PaperRAG/data/2501.12691v1.pdf
# 2025-01-23 20:29:38,215 - root - DEBUG - Figure metadata path: /Users/zehrakorkusuz/PaperRAG/src/paperrag/eval/data/figures/2501.12691v1.json
# 2025-01-23 20:29:38,218 - root - DEBUG - Opening metadata file: /Users/zehrakorkusuz/PaperRAG/src/paperrag/eval/data/figures/2501.12691v1.json
# 2025-01-23 20:29:38,234 - root - DEBUG - Loaded metadata: [
#   {
#     "caption": "Figure 3: Expected trajectory NA(t) under normally distributed rates. (a) - (b) We consider treatment A, which invokes a normally distributed response \u03bb \u223c N(\u00b5A, \u03c3 2 A). Hence it can potentially include a mixture of positive/negative \u03bb, as captured by blue/red cells in panel (a). (c) NA(t) vs. t begins with an exponential decay driven by the average E(\u03bb) = \u00b5A, but at t = \u00b5A/\u03c3 2 A begins to reemerge, leading to a long term proliferation driven by V (\u03bb) = \u03c32 A. (d) The density function PA \u03bb (z; t) at three different time points t = 0, 12.5 and 25. As the population dynamics progresses the rapidly decaying lineages (large \u03bb) are eliminated, and the \u03bb distribution progressively tends towards the longer living cells (smaller and potentially negative \u03bb). Hence, at t \u2192 \u221e the initially negligible sub-population of \u03bb-negative cells begins to dominate the population dynamics. (e) We collected data from 78 empirical population response patterns (i = 1, . . . , 78). In experiment i an initial population of Ni0 cancer cells were subject to a specific chemotherapeutic agent (grey). Here we display the normalized population ni(t) = Ni(t)/Ni0 as obtained from the ith cancer/treatment combination. Three specific experimental combinations are highlighted (red shades). For example, in dark red we track cell-line PC9\u2019s response to Gefitinib, as represented by the image pointed to by the dark red arrow. The other two combinations are also shown. (f) We focus on the three highlighted ni(t) plots of panel (e). Despite the diversity of the observed ni(t) (circles), we find that they can be well-approximated by Eq. (7) under the appropriate selection of \u00b5i, \u03c3i. (g) To test this systematically we plot ni(t) vs. fi(t) = \u2212\u00b5it + \u03c32 i t 2/2. We find that all data-points (grey) of panel (e) collapse onto the universal black solid line predicted by Eq. (7). This clearly shows that the diverse response patterns observed across the 78 experiments all fall within the universal prediction of (7). The three selected ni(t) from panel (f) are highlighted (red shades). (h) We consider two competing treatments A = 1 (dark red) and A = 2 (light red), in which \u00b51 > \u00b52 and \u03c31 > \u03c32. (i) The short term response clearly indicates that 1 is preferable over 2, as it eliminates the undesired cells more rapidly. (j) However, in the long term, due to 1\u2019s higher variance (\u03c31 > \u03c32), we observe a crossover effect: while under 2 the cells continue to decay, the 1 treated population changes course, and begins to rapidly proliferate. This highlights the crucial clinical implications of population heterogeneity (\u03c3A) over its average (\u00b5A). (k) - (m) We observe several instances of such crossover dynamics within our 78 experimental treatments (see Supplementary Section 6.3).",
#     "captionBoundary": {
#       "x1": 70.86599731445312,
#       "x2": 524.4132690429688,
#       "y1": 510.5554504394531,
#       "y2": 779.0239868164062
#     },
#     "figType": "Figure",
#     "imageText": [
#       "Gefitinib",
#       "PC9",
#       "Gemcitibin",
#       "G361",
#       "Cisplatin",
#       "G361",
#       "m",
#       "1",
#       "s",
#       "1",
#       "m",
#       "2",
#       "s",
#       "2",
#       "m",
#       "=",
#       "0.17",
#       "s",
#       "=",
#       "0.04",
#       "m",
#       "=",
#       "0.29",
#       "s",
#       "=",
#       "0.12",
#       "m",
#       "=",
#       "0.34",
#       "s",
#       "=",
#       "0.11",
#       "(k)",
#       "(l)",
#       "(m)",
#       "(b)(a)",
#       "(c)",
#       "(e)",
#       "(g)",
#       "(i)(h)",
#       "(f)",
#       "(j)",
#       "(d)",
#       "t",
#       "=",
#       "0t",
#       "=",
#       "12.5t",
#       "=",
#       "25",
#       "/",
#       "s\ufffd",
#       "~e",
#       "1",
#       "2s2",
#       "t",
#       "2",
#       "t",
#       "=",
#       "m",
#       "t",
#       "A",
#       "A",
#       "A",
#       "~e",
#       "-m",
#       "A",
#       "s",
#       "A",
#       "m",
#       "A",
#       "SKBR3;",
#       "Gemcitibin",
#       "G361;",
#       "VX-680",
#       ")",
#       "n",
#       "i(t",
#       "10",
#       "2",
#       "10",
#       "0",
#       "10",
#       "-2",
#       "0",
#       "20",
#       "40",
#       "t",
#       "PC9;",
#       "Gefitinib",
#       "PC9;",
#       "Docetaxel",
#       ")",
#       "n",
#       "i(t",
#       "10",
#       "2",
#       "10",
#       "0",
#       "10",
#       "-2",
#       "0",
#       "20",
#       "40",
#       "t",
#       "PC9;",
#       "Gefitinib",
#       "PC9;VX-680",
#       ")",
#       "n",
#       "i(t",
#       "10",
#       "2",
#       "10",
#       "0",
#       "10",
#       "-2",
#       "0",
#       "20",
#       "40",
#       "t",
#       "1",
#       "2",
#       ")",
#       "N",
#       "A",
#       "(t",
#       "10",
#       "6",
#       "10",
#       "5",
#       "10",
#       "4",
#       "0",
#       "2",
#       "4",
#       "6",
#       "t",
#       ")",
#       "1",
#       "2",
#       "N",
#       "A",
#       "(t",
#       "10",
#       "6",
#       "10",
#       "4",
#       "10",
#       "2",
#       "0",
#       "10",
#       "20",
#       "t",
#       "2",
#       "0",
#       ")",
#       "1",
#       ";t",
#       "=",
#       "P",
#       "A",
#       "l(z",
#       "4",
#       "2",
#       "0",
#       "0",
#       "1",
#       "2",
#       "z",
#       ")",
#       "n",
#       "i(t",
#       "10",
#       "2",
#       "10",
#       "0",
#       "10",
#       "-2",
#       "-8",
#       "-4",
#       "0",
#       "4",
#       "f",
#       "i",
#       "(t)",
#       ")",
#       "n",
#       "i(t",
#       "t",
#       "0",
#       "20",
#       "40",
#       "t",
#       "0",
#       "20",
#       "40",
#       "t",
#       "n",
#       "i(t",
#       ")",
#       "0",
#       "20",
#       "40",
#       "10",
#       "1",
#       "10",
#       "0",
#       "10",
#       "-1",
#       "10",
#       "-2",
#       "10",
#       "-3",
#       "0",
#       "20",
#       "40",
#       "t",
#       "0.5",
#       "1",
#       "P",
#       "A",
#       "l(z",
#       ";t",
#       ")",
#       "0",
#       "-4",
#       "-2",
#       "0",
#       "2",
#       "4",
#       "z",
#       ")",
#       "N",
#       "A",
#       "(t",
#       "10",
#       "8",
#       "10",
#       "4",
#       "10",
#       "0",
#       "0",
#       "15",
#       "30",
#       "t",
#       ")",
#       "=",
#       "0",
#       "l(z",
#       ";t",
#       "A",
#       "P",
#       "A",
#       "1",
#       "0.5",
#       "0",
#       "1",
#       "2",
#       "3",
#       "z"
#     ],
#     "name": "3",
#     "page": 14,
#     "regionBoundary": {
#       "x1": 161.28,
#       "x2": 427.2,
#       "y1": 71.52,
#       "y2": 496.79999999999995
#     },
#     "renderDpi": 300,
#     "renderURL": "/app/outputs/2501.12691v1-Figure3-1.png"
#   },
#   {
#     "caption": "Figure 2: Three classes of the expected population dynamics NA(t). Under PA \u03bb (z; t = 0) in (8) we predict that NA(t) can follow three distinct paths. (a) In case \u03bbmin > 0 we observe exponential remission. (b) As an example we consider a bi-modal PA \u03bb (z; t = 0), as commonly observed in antibiotic bacterial persistence: most bacteria exhibit a rapid decay (large \u03bb), while a small minority persist (small \u03bb). These two \u03bb values are depicted by dark/light blue shades in panel (a). (c) The result is that NA(t) \u223c e\u2212\u03bbmint (dashed line), driven by the slowest decaying sub-population. Still, despite the slow \u03bbmin, this class predicts a long-term exponential decay of the form of Eq. (1). Such dynamics guarantees to eliminate the undesired population within logarithmic timescales, as in (2). We also show an actual stochastic realization of Nt (blue) conducted under the bi-modal PA \u03bb (z; t = 0) of panel (b). (d) - (f) In case PA \u03bb (z; t = 0) is bounded at z = 0 we have \u03bbmin = 0, leading to slow remission. Such treatments completely suppress growth (i.e. no \u03bb < 0), but allow for arbitrarily slow decay rates (blue shades). Here NA(t) (dashed line) follows a slow polynomial death (\u223c t\u2212\u03b1), and hence the typical treatment duration diverges with N0, resulting in successful but inefficient treatment. Such slow decay is also observed under a stochastic realization (green) conducted with PA \u03bb (z; t = 0) of panel (e). (g) - (i) In the presence of negative \u03bbmin (red cells), e.g. under normally distributed rates, the expectation will follow a recurrent dynamics, reemerging with a long term exponential growth, driven by the small seed of positively growing cells that may exist within the original population (panel (i), NA(t), dashed line; Nt, red). Note that here, despite taking PA \u03bb (z; t = 0) from a normal distribution, which in principal allows \u03bb \u2208 (\u2212\u221e,\u221e), we still observe a finite \u03bbmin (panel (h), red dot), due to the finite initial population size N0. These classes, we emphasize, capture the expectation NA(t) but disregard potential stochastic deviations, i.e. VA(t), as represented by the grey shaded in Fig. 1b,d. Taking the latter into account, via QA and TA in (14) and (15), we detect conditions where, e.g., extinction may precede recurrence. Under such conditions, while NA(t) reemerges, as per the recurrent class, the actual observed treatment outcome (Nt) may, with high likelihood, be successful and, in fact, reach Nt = 0, thus averting the recurrent branch. Therefore, our full analysis does not stop at NA(t), but also incorporates VA(t) and its subsequent parameters TA and QA.",
#     "captionBoundary": {
#       "x1": 70.86599731445312,
#       "x2": 524.4138793945312,
#       "y1": 516.7575073242188,
#       "y2": 775.2630615234375
#     },
#     "figType": "Figure",
#     "imageText": [
#       "Recurrent",
#       "Slow",
#       "remission",
#       "Exponential",
#       "remission",
#       "l",
#       "min",
#       "~e",
#       "-",
#       "l",
#       "min",
#       "t",
#       "l",
#       "min",
#       "<",
#       "0",
#       "(g)",
#       "(i)(h)",
#       ")",
#       "N",
#       "C",
#       "(t",
#       "10",
#       "6",
#       "10",
#       "4",
#       "10",
#       "2",
#       "0",
#       "10",
#       "20",
#       "30",
#       "40",
#       "t",
#       "0",
#       ")",
#       "P",
#       "C",
#       "l(",
#       "z;",
#       "t",
#       "=",
#       "1",
#       "0",
#       "0",
#       "2",
#       "4",
#       "l",
#       "N",
#       "C",
#       "(t)",
#       "N",
#       "t",
#       "N",
#       "B",
#       "(t)",
#       "N",
#       "t",
#       "N",
#       "t",
#       "(a)",
#       "(b)",
#       "(c)",
#       "N",
#       "A",
#       "(t)",
#       "0",
#       ")",
#       "P",
#       "A",
#       "l(",
#       "z;",
#       "t=",
#       "9",
#       "6",
#       "3",
#       "0",
#       "0.2",
#       "0.4",
#       "0.6",
#       "l",
#       ")",
#       "N",
#       "A",
#       "(t",
#       "10",
#       "6",
#       "10",
#       "3",
#       "10",
#       "0",
#       "0",
#       "50",
#       "100",
#       "t",
#       "~e",
#       "-",
#       "l",
#       "min",
#       "t",
#       "l",
#       "min",
#       ">",
#       "0",
#       "(d)",
#       "(e)",
#       "(f)",
#       ")",
#       "N",
#       "B",
#       "(t",
#       "10",
#       "6",
#       "10",
#       "3",
#       "10",
#       "0",
#       "t",
#       "10",
#       "0",
#       "10",
#       "1",
#       "10",
#       "2",
#       "10",
#       "3",
#       "0",
#       ")",
#       "P",
#       "B",
#       "l(",
#       "z;",
#       "t",
#       "=",
#       "4",
#       "2",
#       "0",
#       "0",
#       "1",
#       "l",
#       "~t",
#       "-a",
#       "l",
#       "min",
#       "=",
#       "0"
#     ],
#     "name": "2",
#     "page": 13,
#     "regionBoundary": {
#       "x1": 92.64,
#       "x2": 500.15999999999997,
#       "y1": 70.8,
#       "y2": 510.0
#     },
#     "renderDpi": 300,
#     "renderURL": "/app/outputs/2501.12691v1-Figure2-1.png"
#   },
#   {
#     "caption": "Figure 1: The malignancy-treatment interplay. (a) The dynamics of a homogeneous cell population under treatment A. In each time step cells duplicate, remain idle or decay stochastically at rates r+, r0 and r\u2212, respectively. These rates depend on the cell-type and on A\u2019s efficacy. The resulting population dynamics is characterized by the discrete random variable Nt, which describes the cell population at time t. If at some instance Nt hits zero (blue horizontal line), the malignant population is eliminated and the treatment is deemed successful. (b) Due to the stochastic nature of Nt each realization of the dynamics leads to a different outcome (orange lines). We can characterize this variability by reducing it into two statistical parameters: The expectation NA(t) (red), which decays exponentially at rate \u03bb = r\u2212 \u2212 r+, and the standard deviation \u221a VA(t) (grey), which captures the",
#     "captionBoundary": {
#       "x1": 70.86599731445312,
#       "x2": 524.4129028320312,
#       "y1": 499.26446533203125,
#       "y2": 582.427001953125
#     },
#     "figType": "Figure",
#     "imageText": [
#       "\ud835\udc9b",
#       ",\ud835\udc96",
#       ";\ud835\udc95",
#       "=",
#       "\ud835\udfce",
#       "\ud835\udc77",
#       "\ud835\udc93\ud835\udc68",
#       "\ud835\udc99",
#       ",\ud835\udc9a",
#       ";\ud835\udc95",
#       "=",
#       "\ud835\udfce",
#       "\ud835\udc77",
#       "\ud835\udf40",
#       ",\ud835\udf4b",
#       "\ud835\udc68",
#       "\ud835\udc93+",
#       "\ud835\udc93\u2212",
#       "\ud835\udf40",
#       "\ud835\udf4b",
#       "Population",
#       "heterogeneity",
#       "&",
#       "stochastic",
#       "dynamics",
#       "\ud835\udc78\ud835\udc68",
#       "\u2264",
#       "\ud835\udfcf",
#       "\ud835\udc7b\ud835\udc68",
#       "\u223c",
#       "\ud835\udc25\ud835\udc27\ud835\udc75\ud835\udfce",
#       "\ud835\udc68",
#       "\ud835\udc7b\ud835\udc69",
#       "\u2192",
#       "\ud835\udc75\ud835\udfce",
#       "\ud835\udf37",
#       "\ud835\udc78\ud835\udc6a",
#       ">",
#       "\ud835\udfcf",
#       "\ud835\udc7b\ud835\udc6a",
#       "\u2192",
#       "\u221e",
#       "\ud835\udc78\ud835\udc69",
#       "\u2264",
#       "\ud835\udfcf",
#       "\ud835\udc6a",
#       "Treatment",
#       "\ud835\udc68",
#       "Stochastic",
#       "population",
#       "dynamics",
#       "\ud835\udc69",
#       "\ud835\udc68",
#       "\ud835\udc69",
#       "Potential",
#       "outcomes(e)",
#       "Time",
#       "Population",
#       "heterogeneity(c)",
#       "Treatment",
#       "success",
#       "and",
#       "duration",
#       "(d)",
#       "Success",
#       "time",
#       "\ud835\udc7b\ud835\udc68",
#       "Treatment",
#       "success",
#       "likely",
#       "\ud835\udce5\ud835\udc68(\ud835\udc95)",
#       "\ud835\udc78",
#       "\ud835\udc68",
#       "\u2264",
#       "\ud835\udfcf",
#       "Time",
#       "\ud835\udcdd\ud835\udc68(\ud835\udc95)",
#       "Treatment",
#       "\ud835\udc68",
#       "(a)",
#       "Expectation",
#       "&",
#       "variance(b)",
#       "Real.",
#       "3\ud835\udcdd",
#       "\ud835\udc95",
#       "=",
#       "\ud835\udc86\u2212\ud835\udf40\ud835\udc95",
#       "Real.",
#       "1",
#       "Real.",
#       "2",
#       "Time",
#       "\ud835\udce5\ud835\udc68(\ud835\udc95)",
#       "\ud835\udcdd\ud835\udc68(\ud835\udc95)",
#       "\ud835\udc75\ud835\udc95",
#       "Time",
#       "\ud835\udc93\ud835\udfce",
#       "\ud835\udc93\u2212",
#       "\ud835\udc93+",
#       "\ud835\udc75\ud835\udc95",
#       "=",
#       "\ud835\udfce",
#       "Treatment",
#       "success",
#       "\ud835\udc75\ud835\udc95",
#       "=",
#       "\ud835\udfcf",
#       "\ud835\udc75\ud835\udc95",
#       "=",
#       "\ud835\udfd0",
#       "\ud835\udc75\ud835\udc95",
#       "=",
#       "\ud835\udfd1",
#       "\ud835\udc75\ud835\udc95",
#       "=",
#       "\ud835\udfd2",
#       "\ud835\udc6a",
#       "\ud835\udc93+,",
#       "\ud835\udc93_",
#       "\ud835\udc93\ud835\udfce,",
#       "\ud835\udc93\ud835\udfce"
#     ],
#     "name": "1",
#     "page": 12,
#     "regionBoundary": {
#       "x1": 126.0,
#       "x2": 466.08,
#       "y1": 72.72,
#       "y2": 490.08
#     },
#     "renderDpi": 300,
#     "renderURL": "/app/outputs/2501.12691v1-Figure1-1.png"
#   },
#   {
#     "caption": "Figure 5: Recurrent dynamics. (a) - (b) We consider normally distributed rates in which \u03bb, \u03c6 \u223c N(\u00b5A, \u03c3 2 A, \u03bdA, \u03b4 2 A). The distribution for \u03c6 is truncated at zero, to ensure positive rates (see Supplementary Section 6.2). (c) While in this class we predict that NA(t) will reemerge, the actual stochastic realizations Nt, namely the observed dynamics, may, under some conditions, avoid recurrence and reach extinction. This is expected, if, during the population dip, when Nt is at its minimum point (t = tmin), a large enough fluctuation drives it towards Nt = 0. Hence we seek QA = qA(t = tmin), i.e. the value of our statistic qA(t) at the population\u2019s most vulnerable time point. (d) In Supplementary Section 4 we derive QA = qA(t = tmin), allowing us to predict the success/recurrence probability. (e) To test the condition presented in panel (c), we examined an ensemble of 6, 400 different stochastic treatment scenarios spanning a broad range of parameter sets (N0, \u00b5A, \u03c3A, \u03bdA, \u03b4A). Each scenario was implemented across M = 100 independent realizations, allowing us to extract the success probability P (Nt = 0) from the fraction of realizations that ended in population extinction. For each scenario we also calculated QA as shown in panel (d). Plotting P (Nt = 0) vs. QA (grey dots) we find that indeed QA \u2264 1 (vertical dashed line) sharply splits between the recurrent scenarios (P (Nt = 0) \u2192 0, right) and the successful ones (P (Nt = 0) \u2192 1, left). Hence, our formalism allows us to evaluate a priori, through QA, the potential efficacy of a given treatment, and its probability for recurrence. This prediction is encapsulated within the single parameter QA in (14), as determined by the malignant population size N0 and by its distributed response PA \u03bb,\u03c6(z, u; t = 0) to the proposed treatment. (f) The recurrent vs. successful phase boundary in the N0, \u00b5A, \u03c3A phase space (grey surface). The predicted boundary sharply splits between our successful (above 90% remission; green) and failed (above 90% recurrence, red) simulated scenarios. The arrows point in the direction of the ideal treatment: large average response (high \u00b5A) and a low response variability across the cellular population (small \u03c3A). These considerations play an exceeding role as the initial population size N0 is increased, and therefore under small N0 the conditions for success are enhanced. (g) - (i) We focused on three specific scenarios from our ensemble: QA = 5\u00d7 10\u22123 (green), QA = 1 (orange) and QA = 15 (red). For each of these scenarios we show the M = 100 realizations of Nt vs. t. As expected, each realization follows a distinct sequence, a testament to the random nature of Nt. The crucial point is that under QA \u226a 1 all realizations end successfully in Nt = 0 (green), while for QA \u226b 1 they all exhibit the predicted recurrence (red). In between, under QA = 1, we observe borderline behavior (orange), with some realizations (\u223c 40%) ending in recurrence, while others (\u223c 60%) terminating in the desired remission.",
#     "captionBoundary": {
#       "x1": 70.86598205566406,
#       "x2": 524.4136962890625,
#       "y1": 480.8734436035156,
#       "y2": 782.2188720703125
#     },
#     "figType": "Figure",
#     "imageText": [
#       "(d)",
#       ")",
#       "=",
#       "0",
#       ",u",
#       ";t",
#       ",",
#       "(z",
#       "Q",
#       "A",
#       "=",
#       "q",
#       "A",
#       "(t",
#       "min",
#       ")",
#       "zuP",
#       "A",
#       "l",
#       "t",
#       "m",
#       "in",
#       "(a)",
#       "(b)",
#       "(c)",
#       "N",
#       "t",
#       "10",
#       "6",
#       "10",
#       "4",
#       "10",
#       "2",
#       "0",
#       "5",
#       "10",
#       "t",
#       "N",
#       "0",
#       "ms",
#       "1",
#       "Q",
#       "A",
#       "=",
#       "(g)",
#       "(h)",
#       "(i)",
#       "(e)",
#       "(f)",
#       "-3",
#       "A",
#       "=",
#       "6",
#       "\u00d7",
#       "10",
#       "=",
#       "13Q",
#       "A",
#       "=",
#       "1.0Q",
#       "AA",
#       "Q",
#       "A",
#       "Remission",
#       "Recurrent",
#       "N",
#       "t",
#       "10",
#       "6",
#       "10",
#       "5",
#       "10",
#       "4",
#       "0",
#       "5",
#       "10",
#       "t",
#       "N",
#       "t",
#       "10",
#       "6",
#       "10",
#       "3",
#       "10",
#       "0",
#       "0",
#       "10",
#       "20",
#       "30",
#       "t",
#       "N",
#       "t",
#       "10",
#       "6",
#       "10",
#       "3",
#       "10",
#       "0",
#       "0",
#       "5",
#       "10",
#       "t",
#       ")",
#       "t",
#       "=",
#       "0",
#       "P",
#       "(N",
#       "1",
#       "0.5",
#       "0",
#       "Q",
#       "A",
#       "10",
#       "4",
#       "10",
#       "2",
#       "10",
#       "0",
#       "10",
#       "-2",
#       "10",
#       "-4"
#     ],
#     "name": "5",
#     "page": 16,
#     "regionBoundary": {
#       "x1": 114.72,
#       "x2": 478.08,
#       "y1": 70.8,
#       "y2": 473.76
#     },
#     "renderDpi": 300,
#     "renderURL": "/app/outputs/2501.12691v1-Figure5-1.png"
#   },
#   {
#     "caption": "Figure 4: Slow remission. (a) - (b) To observe our slow remission class we consider three competing treatments A = 1, 2, 3, each characterized by a different \u0393(\u03b1, l)-distributed response pattern (\u03b1 = 1, l = 1, red; \u03b1 = 2, l = 1, orange; \u03b1 = 3, l = 1, green). (c) The observed population Nt vs. t as obtained under treatments 1 (red), 2 (orange) and 3 (green). For each treatment we show M = 100 independent realizations, starting from N0 = 107. (d) Averaging over all M realizations we extract NA(t). As predicted in (17), we find that NA(t) \u223c t\u2212\u03b1 for \u03b1 = 1, 2, 3 (red, orange and green solid lines, respectively). This confirms our predicted slow power-law decay. (e) VA(t) vs. t (circles) as obtained from the realizations Nt of panel (c). Once again, we observe the scaling (solid lines) predicted in Eq. (17). (f) qA(t) vs. t (circles), alongside our predicted scaling (solid lines). Our analysis predicts that the time TA for the treatment to reach success occurs when QA \u2264 1 (horizontal dashed line). Hence the intersection between qA(t) (colored lines) and the horizontal dashed line represents the expected population extinction time TA. (g) Using our stochastic realizations of panel (c) we extract the observed extinction time TObs A (A = 1, 2, 3) as the time when half of all realizations reached Nt = 0, namely when P (Nt = 0) = 1/2 (vertical dashed lines). Indeed, for t > TObs",
#     "captionBoundary": {
#       "x1": 70.86590576171875,
#       "x2": 524.4131469726562,
#       "y1": 473.74346923828125,
#       "y2": 610.7049560546875
#     },
#     "figType": "Figure",
#     "imageText": [
#       "0",
#       "~N",
#       "1/4",
#       "0",
#       "0",
#       "~N",
#       "1/3",
#       "~N",
#       "1/2",
#       "-2",
#       "~t",
#       "-3/2~t",
#       "-1",
#       "~t",
#       "-2",
#       "~t",
#       "~t",
#       "-1",
#       "~t",
#       "0",
#       "~t",
#       "-3",
#       "~t",
#       "-2",
#       "~t",
#       "-1",
#       "A",
#       "=",
#       "3",
#       "A",
#       "=",
#       "2",
#       "A",
#       "=",
#       "1",
#       "q",
#       "A",
#       "=",
#       "1",
#       "Obs",
#       "3",
#       "2",
#       "T",
#       "Obs",
#       "1",
#       "T",
#       "T",
#       "Obs",
#       "(l)",
#       "(c)(a)",
#       "(i)(h)(g)",
#       "(k)(j)",
#       "(f)",
#       "(b)",
#       "(d)",
#       "(e)",
#       "7",
#       "N",
#       "0",
#       "=",
#       "10",
#       "5",
#       "N",
#       "0",
#       "=",
#       "10",
#       "3",
#       "N",
#       "0",
#       "=",
#       "10",
#       "0",
#       ")",
#       "P",
#       "(N",
#       "t",
#       "=",
#       "1",
#       "0.5",
#       "0",
#       "t",
#       "10",
#       "0",
#       "10",
#       "2",
#       "10",
#       "4",
#       "10",
#       "6",
#       "7",
#       "N",
#       "0",
#       "=",
#       "10",
#       "5",
#       "N",
#       "0",
#       "=",
#       "10",
#       "3",
#       "N",
#       "0",
#       "=",
#       "10",
#       "0",
#       ")",
#       "P",
#       "(N",
#       "t",
#       "=",
#       "1",
#       "0.5",
#       "0",
#       "t",
#       "10",
#       "4",
#       "10",
#       "2",
#       "10",
#       "0",
#       "7",
#       "N",
#       "0",
#       "=",
#       "10",
#       "5",
#       "N",
#       "0",
#       "=",
#       "10",
#       "3",
#       "N",
#       "0",
#       "=",
#       "10",
#       "0",
#       ")",
#       "P",
#       "(N",
#       "t",
#       "=",
#       "1",
#       "0.5",
#       "0",
#       "10",
#       "2",
#       "t",
#       "10",
#       "0",
#       "b",
#       "s",
#       "T",
#       "O",
#       "10",
#       "3",
#       "10",
#       "2",
#       "10",
#       "1",
#       "10",
#       "0",
#       "N",
#       "0",
#       "10",
#       "2",
#       "10",
#       "4",
#       "10",
#       "6",
#       "10",
#       "8",
#       "A",
#       "b",
#       "s",
#       "T",
#       "O",
#       "10",
#       "3",
#       "10",
#       "2",
#       "10",
#       "1",
#       "T",
#       "A",
#       "10",
#       "1",
#       "10",
#       "2",
#       "10",
#       "3",
#       "N",
#       "t",
#       "10",
#       "8",
#       "10",
#       "4",
#       "10",
#       "0",
#       "t",
#       "10",
#       "4",
#       "10",
#       "2",
#       "10",
#       "0",
#       "A",
#       "=",
#       "1",
#       "A",
#       "=",
#       "2",
#       "A",
#       "=",
#       "3",
#       ")",
#       "q",
#       "A",
#       "(t",
#       "10",
#       "2",
#       "10",
#       "0",
#       "10",
#       "-2",
#       "t",
#       "V",
#       "A",
#       "(t",
#       ")",
#       "10",
#       "0",
#       "10",
#       "2",
#       "10",
#       "4",
#       "10",
#       "9",
#       "10",
#       "6",
#       "10",
#       "3",
#       "t",
#       "10",
#       "0",
#       "10",
#       "2",
#       "10",
#       "4",
#       ")",
#       "N",
#       "A",
#       "(t",
#       "10",
#       "6",
#       "10",
#       "3",
#       "10",
#       "0",
#       "t",
#       "10",
#       "0",
#       "10",
#       "2",
#       "10",
#       "4",
#       "N",
#       "t",
#       "10",
#       "6",
#       "10",
#       "3",
#       "10",
#       "0",
#       "t",
#       "10",
#       "4",
#       "10",
#       "2",
#       "10",
#       "0",
#       "a",
#       "=",
#       "2",
#       "a",
#       "=",
#       "3",
#       "0",
#       ")",
#       "a",
#       "=",
#       "1",
#       ";t",
#       "=",
#       "P",
#       "A",
#       "l(z",
#       "1",
#       "0.5",
#       "0",
#       "0",
#       "2",
#       "4",
#       "z"
#     ],
#     "name": "4",
#     "page": 15,
#     "regionBoundary": {
#       "x1": 146.16,
#       "x2": 454.32,
#       "y1": 78.48,
#       "y2": 469.44
#     },
#     "renderDpi": 300,
#     "renderURL": "/app/outputs/2501.12691v1-Figure4-1.png"
#   }
# ]
# 2025-01-23 20:29:38,237 - root - DEBUG - Extracted figures: ['/app/outputs/2501.12691v1-Figure3-1.png', '/app/outputs/2501.12691v1-Figure2-1.png', '/app/outputs/2501.12691v1-Figure1-1.png', '/app/outputs/2501.12691v1-Figure5-1.png', '/app/outputs/2501.12691v1-Figure4-1.png']
# 2025-01-23 20:29:38,239 - root - DEBUG - Searching for renderURL ending with: /2501.12691v1-Figure3-1.png
# 2025-01-23 20:29:38,240 - root - DEBUG - Found renderURL for 2501.12691v1-Figure3-1.png: /app/outputs/2501.12691v1-Figure3-1.png
# 2025-01-23 20:29:38,241 - root - DEBUG - Searching for renderURL ending with: /2501.12691v1-Figure2-1.png
# 2025-01-23 20:29:38,245 - root - DEBUG - Found renderURL for 2501.12691v1-Figure2-1.png: /app/outputs/2501.12691v1-Figure2-1.png
# 2025-01-23 20:29:38,246 - root - DEBUG - Searching for renderURL ending with: /2501.12691v1-Figure1-1.png
# 2025-01-23 20:29:38,247 - root - DEBUG - Found renderURL for 2501.12691v1-Figure1-1.png: /app/outputs/2501.12691v1-Figure1-1.png
# 2025-01-23 20:29:38,248 - root - DEBUG - Searching for renderURL ending with: /2501.12691v1-Figure5-1.png
# 2025-01-23 20:29:38,249 - root - DEBUG - Found renderURL for 2501.12691v1-Figure5-1.png: /app/outputs/2501.12691v1-Figure5-1.png
# 2025-01-23 20:29:38,250 - root - DEBUG - Searching for renderURL ending with: /2501.12691v1-Figure4-1.png
# 2025-01-23 20:29:38,250 - root - DEBUG - Found renderURL for 2501.12691v1-Figure4-1.png: /app/outputs/2501.12691v1-Figure4-1.png
# 2025-01-23 20:29:38,256 - root - DEBUG - Figures with metadata: [
#   {
#     "figure": "/app/outputs/2501.12691v1-Figure3-1.png",
#     "metadata": {
#       "caption": "Figure 3: Expected trajectory NA(t) under normally distributed rates. (a) - (b) We consider treatment A, which invokes a normally distributed response \u03bb \u223c N(\u00b5A, \u03c3 2 A). Hence it can potentially include a mixture of positive/negative \u03bb, as captured by blue/red cells in panel (a). (c) NA(t) vs. t begins with an exponential decay driven by the average E(\u03bb) = \u00b5A, but at t = \u00b5A/\u03c3 2 A begins to reemerge, leading to a long term proliferation driven by V (\u03bb) = \u03c32 A. (d) The density function PA \u03bb (z; t) at three different time points t = 0, 12.5 and 25. As the population dynamics progresses the rapidly decaying lineages (large \u03bb) are eliminated, and the \u03bb distribution progressively tends towards the longer living cells (smaller and potentially negative \u03bb). Hence, at t \u2192 \u221e the initially negligible sub-population of \u03bb-negative cells begins to dominate the population dynamics. (e) We collected data from 78 empirical population response patterns (i = 1, . . . , 78). In experiment i an initial population of Ni0 cancer cells were subject to a specific chemotherapeutic agent (grey). Here we display the normalized population ni(t) = Ni(t)/Ni0 as obtained from the ith cancer/treatment combination. Three specific experimental combinations are highlighted (red shades). For example, in dark red we track cell-line PC9\u2019s response to Gefitinib, as represented by the image pointed to by the dark red arrow. The other two combinations are also shown. (f) We focus on the three highlighted ni(t) plots of panel (e). Despite the diversity of the observed ni(t) (circles), we find that they can be well-approximated by Eq. (7) under the appropriate selection of \u00b5i, \u03c3i. (g) To test this systematically we plot ni(t) vs. fi(t) = \u2212\u00b5it + \u03c32 i t 2/2. We find that all data-points (grey) of panel (e) collapse onto the universal black solid line predicted by Eq. (7). This clearly shows that the diverse response patterns observed across the 78 experiments all fall within the universal prediction of (7). The three selected ni(t) from panel (f) are highlighted (red shades). (h) We consider two competing treatments A = 1 (dark red) and A = 2 (light red), in which \u00b51 > \u00b52 and \u03c31 > \u03c32. (i) The short term response clearly indicates that 1 is preferable over 2, as it eliminates the undesired cells more rapidly. (j) However, in the long term, due to 1\u2019s higher variance (\u03c31 > \u03c32), we observe a crossover effect: while under 2 the cells continue to decay, the 1 treated population changes course, and begins to rapidly proliferate. This highlights the crucial clinical implications of population heterogeneity (\u03c3A) over its average (\u00b5A). (k) - (m) We observe several instances of such crossover dynamics within our 78 experimental treatments (see Supplementary Section 6.3).",
#       "captionBoundary": {
#         "x1": 70.86599731445312,
#         "x2": 524.4132690429688,
#         "y1": 510.5554504394531,
#         "y2": 779.0239868164062
#       },
#       "figType": "Figure",
#       "imageText": [
#         "Gefitinib",
#         "PC9",
#         "Gemcitibin",
#         "G361",
#         "Cisplatin",
#         "G361",
#         "m",
#         "1",
#         "s",
#         "1",
#         "m",
#         "2",
#         "s",
#         "2",
#         "m",
#         "=",
#         "0.17",
#         "s",
#         "=",
#         "0.04",
#         "m",
#         "=",
#         "0.29",
#         "s",
#         "=",
#         "0.12",
#         "m",
#         "=",
#         "0.34",
#         "s",
#         "=",
#         "0.11",
#         "(k)",
#         "(l)",
#         "(m)",
#         "(b)(a)",
#         "(c)",
#         "(e)",
#         "(g)",
#         "(i)(h)",
#         "(f)",
#         "(j)",
#         "(d)",
#         "t",
#         "=",
#         "0t",
#         "=",
#         "12.5t",
#         "=",
#         "25",
#         "/",
#         "s\ufffd",
#         "~e",
#         "1",
#         "2s2",
#         "t",
#         "2",
#         "t",
#         "=",
#         "m",
#         "t",
#         "A",
#         "A",
#         "A",
#         "~e",
#         "-m",
#         "A",
#         "s",
#         "A",
#         "m",
#         "A",
#         "SKBR3;",
#         "Gemcitibin",
#         "G361;",
#         "VX-680",
#         ")",
#         "n",
#         "i(t",
#         "10",
#         "2",
#         "10",
#         "0",
#         "10",
#         "-2",
#         "0",
#         "20",
#         "40",
#         "t",
#         "PC9;",
#         "Gefitinib",
#         "PC9;",
#         "Docetaxel",
#         ")",
#         "n",
#         "i(t",
#         "10",
#         "2",
#         "10",
#         "0",
#         "10",
#         "-2",
#         "0",
#         "20",
#         "40",
#         "t",
#         "PC9;",
#         "Gefitinib",
#         "PC9;VX-680",
#         ")",
#         "n",
#         "i(t",
#         "10",
#         "2",
#         "10",
#         "0",
#         "10",
#         "-2",
#         "0",
#         "20",
#         "40",
#         "t",
#         "1",
#         "2",
#         ")",
#         "N",
#         "A",
#         "(t",
#         "10",
#         "6",
#         "10",
#         "5",
#         "10",
#         "4",
#         "0",
#         "2",
#         "4",
#         "6",
#         "t",
#         ")",
#         "1",
#         "2",
#         "N",
#         "A",
#         "(t",
#         "10",
#         "6",
#         "10",
#         "4",
#         "10",
#         "2",
#         "0",
#         "10",
#         "20",
#         "t",
#         "2",
#         "0",
#         ")",
#         "1",
#         ";t",
#         "=",
#         "P",
#         "A",
#         "l(z",
#         "4",
#         "2",
#         "0",
#         "0",
#         "1",
#         "2",
#         "z",
#         ")",
#         "n",
#         "i(t",
#         "10",
#         "2",
#         "10",
#         "0",
#         "10",
#         "-2",
#         "-8",
#         "-4",
#         "0",
#         "4",
#         "f",
#         "i",
#         "(t)",
#         ")",
#         "n",
#         "i(t",
#         "t",
#         "0",
#         "20",
#         "40",
#         "t",
#         "0",
#         "20",
#         "40",
#         "t",
#         "n",
#         "i(t",
#         ")",
#         "0",
#         "20",
#         "40",
#         "10",
#         "1",
#         "10",
#         "0",
#         "10",
#         "-1",
#         "10",
#         "-2",
#         "10",
#         "-3",
#         "0",
#         "20",
#         "40",
#         "t",
#         "0.5",
#         "1",
#         "P",
#         "A",
#         "l(z",
#         ";t",
#         ")",
#         "0",
#         "-4",
#         "-2",
#         "0",
#         "2",
#         "4",
#         "z",
#         ")",
#         "N",
#         "A",
#         "(t",
#         "10",
#         "8",
#         "10",
#         "4",
#         "10",
#         "0",
#         "0",
#         "15",
#         "30",
#         "t",
#         ")",
#         "=",
#         "0",
#         "l(z",
#         ";t",
#         "A",
#         "P",
#         "A",
#         "1",
#         "0.5",
#         "0",
#         "1",
#         "2",
#         "3",
#         "z"
#       ],
#       "name": "3",
#       "page": 14,
#       "regionBoundary": {
#         "x1": 161.28,
#         "x2": 427.2,
#         "y1": 71.52,
#         "y2": 496.79999999999995
#       },
#       "renderDpi": 300,
#       "renderURL": "/app/outputs/2501.12691v1-Figure3-1.png"
#     }
#   },
#   {
#     "figure": "/app/outputs/2501.12691v1-Figure2-1.png",
#     "metadata": {
# ...
#
# <!-- image -->
#
# ## References
#
# | [1]   | Lee Susman, Maryam Kohram, Harsh Vashistha, Jeffrey T Nechleba, Hanna Salman, and Naama Brenner. Individuality and slow dynamics in bacterial growth homeostasis. Proceedings of the National Academy of Sciences , 115(25):E5679-E5687, 2018.                                                 |
# |-------|------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | [2]   | Naama Brenner, CM Newman, Dino Osmanovi'c, Yitzhak Rabin, Hanna Salman, and DL Stein. Universal protein distributions in a model of cell growth and division. Physical Review E , 92(4):042713, 2015.                                                                                          |
# | [3]   | Zvi Tamari, Avihu H Yona, Yitzhak Pilpel, and Naama Barkai. Rapid evolutionary adaptation to growth on an 'unfamiliar'carbon source. BMC genomics , 17(1):1-7, 2016.                                                                                                                           |
# | [4]   | Daniel A Charlebois and G'abor Bal'azsi. Modeling cell population dynamics. In Silico Biology , 13(1-2):21-39, 2019.                                                                                                                                                                           |
# | [5]   | Antonio Di Crescenzo, Virginia Giorno, Amelia G Nobile, and Luigi M Ricciardi. A note on birth-death processes with catastrophes. Statistics & probability letters , 78(14):2248-2257, 2008.                                                                                                   |
# | [6]   | Virginia Giorno and Amelia G Nobile. On a class of birth-death processes with time-varying intensity functions. Applied Mathematics and Computation , 379:125255, 2020.                                                                                                                        |
# | [7]   | Nicolas Bacaer. A short history of mathematical population dynamics , volume 618. Springer, 2011.                                                                                                                                                                                              |
# | [8]   | Iris Keren, Niilo Kaldalu, Amy Spoering, Yipeng Wang, and Kim Lewis. Persister cells and tolerance to antimicrobials. FEMS microbiology letters , 230(1):13-18, 2004.                                                                                                                          |
# | [9]   | Nathalie Q Balaban, Jack Merrin, Remy Chait, Lukasz Kowalik, and Stanislas Leibler. Bacterial persistence as a phenotypic switch. Science , 305(5690):1622-1625, 2004.                                                                                                                         |
# | [10]  | Nathalie Q Balaban, Sophie Helaine, Kim Lewis, Martin Ackermann, Bree Aldridge, Dan I Andersson, Mark P Brynildsen, Dirk Bumann, Andrew Camilli, James J Collins, et al. Definitions and guidelines for research on antibiotic persistence. Nature Reviews Microbiology , 17(7):441-448, 2019. |
# | [11]  | Dan I Andersson. Persistence of antibiotic resistant bacteria. Current opinion in microbiology , 6(5):452-456, 2003.                                                                                                                                                                           |
# | [12]  | Erik Bakkeren, M'ed'eric Diard, and Wolf-Dietrich Hardt. Evolutionary causes and consequences of bacterial antibiotic persistence. Nature Reviews Microbiology , 18(9):479-490, 2020.                                                                                                          |
# | [13]  | Aseel Shomar, Omri Barak, and Naama Brenner. Cancer progression as a learning process. Iscience , page 103924, 2022.                                                                                                                                                                           |
# | [14]  | Asher Brauner, Ofer Fridman, Orit Gefen, and Nathalie Q Balaban. Distinguishing between resistance, tolerance and persistence to antibiotic treatment. Nature Reviews Microbiology , 14(5):320-330, 2016.                                                                                      |
# | [15]  | JosephW Bigger et al. Treatment of staphyloeoeeal infections with penicillin by intermittent sterilisation. Lancet , pages 497-500, 1944.                                                                                                                                                      |
# | [16]  | Baruch Barzel and Ofer Biham. Binomial moment equations for stochastic reaction systems. Physical Review Letters , 106(15):150602, 2011.                                                                                                                                                       |
# | [17]  | Baruch Barzel and Ofer Biham. Stochastic analysis of complex reaction networks using binomial moment equations. Physical Review E , 86(3):031126, 2012.                                                                                                                                        |
# | [18]  | MV Bobkova, TN Korbut, and Ed A Rudak. Description of transient processes in multiplying medium by the physical birth-and-death model. In Journal of Physics: Conference Series , volume 1689, page 012016. IOP Publishing, 2020.                                                              |
# | [19]  | Nicola Bartolomeo, Paolo Trerotoli, and Gabriella Serio. Short-term forecast in the early stage of the covid- 19 outbreak in italy. application of a weighted and cumulative average daily growth rate to an exponential decay model. Infectious Disease Modelling , 6:212-221, 2021.          |
# | [20]  | Kaitlyn E Johnson, Grant Howard, William Mo, Michael K Strasser, Ernesto ABF Lima, Sui Huang, and Amy Brock. Cancer cell population growth kinetics at low densities deviate from the exponential growth model and suggest an allee effect. PLoS biology , 17(8):e3000399, 2019.               |
# | [21]  | S Salem, MS Moussa, and MCM Van Loosdrecht. Determination of the decay rate of nitrifying bacteria. Biotechnology and bioengineering , 94(2):252-262, 2006.                                                                                                                                    |
#
# | [22]   | David G Kendall. On the generalized' birth-and-death' process. The annals of mathematical statistics , 19(1):1-15, 1948.                                                                                                                         |
# |--------|--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | [23]   | Ping Wang, Lydia Robert, James Pelletier, Wei Lien Dang, Francois Taddei, Andrew Wright, and Suckjoon Jun. Robust growth of escherichia coli. Current biology , 20(12):1099-1103, 2010.                                                          |
# | [24]   | A Jacob Berger, E Gigi, L Kupershmidt, Z Meir et al. IRS1 phosphorylation underlies the non-stochastic probability of cancer cells to persist during EGFR inhibition therapy. Nature Cancer , 2:1055-1070, 2021.                                 |
# | [25]   | Ariel Amir, Yuval Oreg, and Yoseph Imry. On relaxations and aging of various glasses. Proceedings of the National Academy of Sciences , 109(6):1850-1855, 2012.                                                                                  |
# | [26]   | Nicolaas Godfried Van Kampen. Stochastic processes in physics and chemistry , volume 1. Elsevier, 1992.                                                                                                                                          |
# | [27]   | Otso Ovaskainen and Baruch Meerson. Stochastic models of population extinction. Trends in ecology & evolution , 25(11):643-652, 2010.                                                                                                            |
# | [28]   | John J Dennehy, Nicholas A Friedenberg, Yul W Yang, and Paul E Turner. Virus population extinction via ecological traps. Ecology Letters , 10(3):230-240, 2007.                                                                                  |
# | [29]   | Yoav Kaplan, Shaked Reich, Elyaqim Oster, Shani Maoz, Irit Levin-Reisman, Irine Ronin, Orit Gefen, Oded Agam, and Nathalie Q Balaban. Observation of universal ageing dynamics in antibiotic persistence. Nature , 600(7888):290-294, 2021.      |
# | [30]   | Stuart Kauffman, Carsten Peterson, Bjorn Samuelsson, and Carl Troein. Random boolean network models and the yeast transcriptional network. Proceedings of the National Academy of Sciences , 100(25):14796- 14799, 2003.                         |
# | [31]   | VY Zaitsev, VE Gusev, Vincent Tournat, and Patrick Richard. Slow relaxation and aging phenomena at the nanoscale in granular materials. Physical review letters , 112(10):108302, 2014.                                                          |
# | [32]   | Forrest W Crawford, Vladimir N Minin, and Marc A Suchard. Estimation for general birth-death processes. Journal of the American Statistical Association , 109(506):730-747, 2014.                                                                |
# | [33]   | Paul C Bressloff. Stochastic processes in cell biology , volume 41. Springer, 2014.                                                                                                                                                              |
# | [34]   | Forrest W Crawford, Lam Si Tung Ho, and Marc A Suchard. Computational methods for birth-death processes. Wiley Interdisciplinary Reviews: Computational Statistics , 10(2):e1423, 2018.                                                          |
# | [35]   | Eric J Stewart, Richard Madden, Gregory Paul, and Fran¸cois Taddei. Aging and death in an organism that reproduces by morphologically symmetric division. PLoS biology , 3(2):e45, 2005.                                                         |
# | [36]   | Xiyun Zhang, Zhongyuan Ruan, Muhua Zheng, Jie Zhou, Stefano Boccaletti, and Baruch Barzel. Epidemic spreading under mutually independent intra- and inter-host pathogen evolution. Nature Communications , 'In print', 2022.                     |
# | [37]   | H. Hahn. Uber die nichtarchimedischen Großensysteme. In Hans Hahn Gesammelte Abhandlungen Band 1/Hans Hahn Collected Works Volume 1 , pages 445 - 499. Springer, 1995.                                                                           |
# | [38]   | Harris S Moyed and Kevin P Bertrand. hipa, a newly recognized gene of escherichia coli k-12 that affects frequency of persistence after inhibition of murein synthesis. Journal of bacteriology , 155(2):768-775, 1983.                          |
# | [39]   | Shaleen B Korch, Thomas A Henderson, and Thomas M Hill. Characterization of the hipa7 allele of es- cherichia coli and evidence that high persistence is governed by (p) ppgpp synthesis. Molecular microbiology , 50(4):1199-1213, 2003.        |
# | [40]   | Edo Kussell, Roy Kishony, Nathalie Q Balaban, and Stanislas Leibler. Bacterial persistence: a model of survival in changing environments. Genetics , 169(4):1807-1814, 2005.                                                                     |
# | [41]   | Christophe d'Enfert. Hidden killers: persistence of opportunistic fungal pathogens in the human host. Current Opinion in Microbiology , 12(4):358-364, 2009.                                                                                     |
# | [42]   | Majeda S Hammoud, Abdullah Al-Taiar, Mervat Fouad, Aditiya Raina, and Ziauddin Khan. Persistent candidemia in neonatal care units: risk factors and clinical significance. International Journal of Infectious Diseases , 17(8):e624-e628, 2013. |
#
# - [44] Lior Atia, Dapeng Bi, Yasha Sharma, Jennifer A Mitchel, Bomi Gweon, Stephan A Koehler, Stephen J DeCamp, Bo Lan, Jae Hun Kim, Rebecca Hirsch, et al. Geometric constraints during epithelial jamming. Nature physics , 14(6):613-620, 2018.
# - [45] Alexei V Tkachenko, Sergei Maslov, Ahmed Elbanna, George N Wong, Zachary J Weiner, and Nigel Goldenfeld. Persistent heterogeneity not short-term overdispersion determines herd immunity to covid-19. arXiv preprint arXiv:2008.08142 , 10(2020.07):26-20162420, 2020.
#
# Figures - Full size
#
# <!-- image -->
#
# <!-- image -->
#
# Population heterogeneity & stochastic dynamics
#
# <!-- image -->
#
# Figure 1. The malignancy-treatment interplay .
#
# <!-- image -->
#
# <!-- image -->
#
# <!-- image -->
#
# Three classes of the expected population dynamics N A ( t ).
#
# <!-- image -->
#
# A
#
# Expected trajectory N A ( t ) under normally distributed rates .
#
# <!-- image -->
#
# Slow remission
#
# .
#
# <!-- image -->
#
# 6
#
# Recurrent dynamics .
#
# <!-- image -->

# %% [markdown]
# Speed to process
# Number of tables extracted
# Number of figures extracted
# Figures metadata & text extracted
#
# File processing
# Folder processing

# %%
evaluation_results
# Out:
# {'Docling': {'elapsed_time': 87.74744701385498,
#   'output_length': 0,
#   'output': ''},
#  'LLMSherpa': {'elapsed_time': 164.5761911869049,
#   'output_length': 0,
#   'output': ''},
#  'Custom LLMSherpa': {'elapsed_time': 148.26967215538025,
#   'output_length': 235551,
#   'output': '[\n    {\n        "id": null,\n        "metadata": {\n            "page_idx": 0,\n            "section_title": "Efficient treatment of heterogeneous malignant cell populations > Uzi Harush,1,2 Ravid Straussman3 and Baruch Barzel1,2,4 January 23, 2025",\n            "type": "chunk",\n            "source": "doc_0",\n            "id": "doc_0_p0_chunk_1"\n        },\n        "page_content": "1. Department of Mathematics, Bar-Ilan University, Ramat-Gan, Israel 52900.",\n        "type": "Document"\n    },\n    {\n        "id": null,\n        "metadata": {\n            "page_idx": 0,\n            "section_title": "Efficient treatment of heterogeneous malignant cell populations > Uzi Harush,1,2 Ravid Straussman3 and Baruch Barzel1,2,4 January 23, 2025",\n            "type": "chunk",\n            "source": "doc_0",\n            "id": "doc_0_p0_chunk_2"\n        },\n        "page_content": "2. The Gonda Multidisciplinary Brain Research Center, Bar-Ilan University, Ramat-Gan, Israel 52900.",\n        "type": "Document"\n    },\n    {\n        "id": null,\n        "metadata": {\n            "page_idx": 0,\n            "section_title": "Efficient treatment of heterogeneous malignant cell populations > Uzi Harush,1,2 Ravid Straussman3 and Baruch Barzel1,2,4 January 23, 2025",\n            "type": "chunk",\n            "source": "doc_0",\n            "id": "doc_0_p0_chunk_3"\n        },\n        "page_content": "3. Department of Molecular Cell Biology, Weizmann Institute of Science, Rehovot, Israel 76100.",\n        "type": "Document"\n    },\n    {\n        "id": null,\n        "metadata": {\n            "page_idx": 0,\n            "section_title": "Efficient treatment of heterogeneous malignant cell populations > Uzi Harush,1,2 Ravid Straussman3 and Baruch Barzel1,2,4 January 23, 2025",\n            "type": "chunk",\n            "source": "doc_0",\n            "id": "doc_0_p0_chunk_4"\n        },\n        "page_content": "4. The Network Science Institute, Northeastern University, Boston, MA., 02115, US.",\n        "type": "Document"\n    },\n    {\n        "id": null,\n        "metadata": {\n            "page_idx": 0,\n            "section_title": "Efficient treatment of heterogeneous malignant cell populations > Uzi Harush,1,2 Ravid Straussman3 and Baruch Barzel1,2,4 January 23, 2025",\n            "type": "chunk",\n            "source": "doc_0",\n            "id": "doc_0_p0_chunk_5"\n        },\n        "page_content": "When confronted with an undesired cell population, such as bacterial infections or tumors, we seek the most effective treatment, designed to eliminate the population as rapidly as possible.\\nA common practice is to monitor the cells\\u2019 short-term response to the treatment, and from that, extrapolate the eventual treatment outcome, i.e.\\nwill it eradicate the cells, and if yes - at what timescales.\\nUnderlying this approach is the assumption that the cells exhibit a homogeneous response to the treatment, and hence the early response patterns can be naturally extended to later times.\\nRecent experiments on cancer cell populations, however, indicate a significant level of cellular heterogeneity, undermining this classic assessment protocol of treatment efficacy.\\nWe, therefore, develop here a stochastic framework, to analytically predict the temporal dynamics of a heterogeneous cell population.\\nQuite often, we find, the average cellular parameters, governing the short-term response, fail to predict the actual treatment outcome.\\nIn contrast, our analysis, which also incorporates the population\\u2019s variability, helps identify the relevant statistical parameters, which in turn, enable us to predict the full trajectory of the cell population, and specifically - the likelihood and typical timescales for remission.",\n        "type": "Document"\n    },\n    {\n        "id": null,\n        "metadata": {\n            "page_idx": 0,\n            "section_title": "Efficient treatment of heterogeneous mali ...
#  'Docling Images': {'elapsed_time': 136.89149498939514,
#   'output_length': 76214,
#   'output': "## Efficient treatment of heterogeneous malignant cell populations\n\nUzi Harush, 1 , 2 Ravid Straussman 3 and Baruch Barzel 1 , 2 , 4\n\nJanuary 23, 2025\n\n- 1. Department of Mathematics, Bar-Ilan University, Ramat-Gan, Israel 52900.\n- 2. The Gonda Multidisciplinary Brain Research Center, Bar-Ilan University, Ramat-Gan, Israel 52900.\n- 3. Department of Molecular Cell Biology, Weizmann Institute of Science, Rehovot, Israel 76100.\n- 4. The Network Science Institute, Northeastern University, Boston, MA., 02115, US.\n\nWhen confronted with an undesired cell population, such as bacterial infections or tumors, we seek the most effective treatment, designed to eliminate the population as rapidly as possible. A common practice is to monitor the cells' short-term response to the treatment, and from that, extrapolate the eventual treatment outcome, i.e . will it eradicate the cells, and if yes - at what timescales. Underlying this approach is the assumption that the cells exhibit a homogeneous response to the treatment, and hence the early response patterns can be naturally extended to later times. Recent experiments on cancer cell populations, however, indicate a significant level of cellular heterogeneity, undermining this classic assessment protocol of treatment efficacy. We, therefore, develop here a stochastic framework, to analytically predict the temporal dynamics of a heterogeneous cell population. Quite often, we find, the average cellular parameters, governing the short-term response, fail to predict the actual treatment outcome. In contrast, our analysis, which also incorporates the population's variability, helps identify the relevant statistical parameters, which in turn, enable us to predict the full trajectory of the cell population, and specifically - the likelihood and typical timescales for remission.\n\nThe exponential decay is a hallmark of many population dynamical systems driven by birth and death processes. 1-7 Some examples include bacterial populations under antibiotic treatment, 8-15 chemical compounds undergoing degradation, 16,17 or radioactive processes 18 , all of whom follow the universal form\n\nN t = N 0 e -λt . (1)\n\nUnder λ > 0 this captures a rapid exponential decay of the population, with a typical timescale τ = 1 /λ , ensuring the population's elimination within t sufficiently greater than τ .\n\nIn clinical applications this exponential nature of N t is often taken for granted, 19,20 e.g ., when estimating the desired dose and duration of a specific treatment. For example, consider antibiotics administered against a bacterial infection. By tracking the response of the bacterial population over the course of several hours, one can evaluate λ , extrapolate the long term behavior of N t via (1), and by that, derive the treatment duration T that ensures N t = T ≪ 1, i.e . the time when almost no surviving bacteria remain. 21 Hence a short-term observation of N t can directly provide us with information on the treatment effectiveness over time. Specifically,\n\nsetting N T ≪ 1 in Eq. (1) we obtain\n\nT ≳ 1 λ ln N 0 , (2)\n\na logarithmic dependence on the initial population size, ensuring that even a macroscopic population, with N 0 → ∞ , can be eradicated within a relatively small (logarithmically bounded) timescale.\n\nThe challenge is that many relevant systems incorporate a mixture of birth/death rates, as their initial population is intrinsically heterogeneous 22-24 (Fig. 1). A classic example for such mixture is observed in antibiotic persistence, 9-12 where a majority of rapidly decaying bacteria (large λ ) coexist alongside a small minority of persistent cells (small λ ). This persistent minority outlives the designated treatment time T , leaving bacterial traces that may reemerge after the treatment is ceased. The resulting, well-documented, deviation from (1) can, in this case, be rectified quite simply by introducing two timescales: λ 1 and λ 2 for the rapid/slow decaying s ...
